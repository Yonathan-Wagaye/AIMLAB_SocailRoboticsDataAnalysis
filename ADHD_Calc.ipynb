# %%
import pandas as pd

# %%
file_path = './Pre-Experiment-1.csv'
df = pd.read_csv(file_path)

# %%
df = df.iloc[4:]
df = df.iloc[:, 2:]

# %%
new_columns = { df.columns[i]: f'Q{i}' for i in range(18)}

# %%
df = df.rename(columns = new_columns)

# %%
df = df.drop(df.index[18])

# %%
df
# Out:
#             Q0          Q1          Q2          Q3          Q4          Q5  \
# 4    Sometimes   Sometimes      Rarely       Often   Sometimes       Often
# 5    Sometimes       Often      Rarely      Rarely       Often   Sometimes
# 6        Never       Never       Never   Sometimes   Sometimes       Never
# 7    Sometimes      Rarely   Sometimes  Very Often   Sometimes   Sometimes
# 8       Rarely      Rarely      Rarely   Sometimes   Sometimes      Rarely
# 9    Sometimes   Sometimes      Rarely       Often   Sometimes      Rarely
# 10   Sometimes  Very Often   Sometimes      Rarely      Rarely       Often
# 11   Sometimes      Rarely   Sometimes       Often       Often   Sometimes
# 12       Often       Often   Sometimes  Very Often       Often   Sometimes
# 13       Never   Sometimes      Rarely      Rarely       Never      Rarely
# 14      Rarely   Sometimes      Rarely   Sometimes       Often   Sometimes
# ...

# %%
response_mapping_one = {
    'Never': 0,
    'Rarely': 0,
    'Sometimes': 1,
    'Often': 1,
    'Very Often': 1
}

response_mapping_two = {
    'Never': 0,
    'Rarely': 0,
    'Sometimes': 0,
    'Often': 1,
    'Very Often': 1
}


def calculate_adhd_score(row):
    score = 0
    for q in ['Q0', 'Q1', 'Q2']:
        score += response_mapping_one[row[q]]
    for q in ['Q3', 'Q4', 'Q5']:
         score += response_mapping_two[row[q]]     
    return score

# %%
df['Part_A_Score'] = df.apply(calculate_adhd_score, axis=1)
df['ADHD_Indication'] = df['Part_A_Score'] >= 4

# %%
df
# Out:
#             Q0          Q1          Q2          Q3          Q4          Q5  \
# 4    Sometimes   Sometimes      Rarely       Often   Sometimes       Often
# 5    Sometimes       Often      Rarely      Rarely       Often   Sometimes
# 6        Never       Never       Never   Sometimes   Sometimes       Never
# 7    Sometimes      Rarely   Sometimes  Very Often   Sometimes   Sometimes
# 8       Rarely      Rarely      Rarely   Sometimes   Sometimes      Rarely
# 9    Sometimes   Sometimes      Rarely       Often   Sometimes      Rarely
# 10   Sometimes  Very Often   Sometimes      Rarely      Rarely       Often
# 11   Sometimes      Rarely   Sometimes       Often       Often   Sometimes
# 12       Often       Often   Sometimes  Very Often       Often   Sometimes
# 13       Never   Sometimes      Rarely      Rarely       Never      Rarely
# 14      Rarely   Sometimes      Rarely   Sometimes       Often   Sometimes
# ...

# %%
def calculate_percentage(df):       
    adhd_percentage = (df['ADHD_Indication'].sum() / len(df)) * 100
    return round(adhd_percentage,2)

# %%
print("Total number of participants: ", len(df))
print("Possible ADHD participants: ",df['ADHD_Indication'].sum() )
print(f"Possible ADHD: {calculate_percentage(df)}%")
# Out:
# Total number of participants:  25
# Possible ADHD participants:  10
# Possible ADHD: 40.0%
